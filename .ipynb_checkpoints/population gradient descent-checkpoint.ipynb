# %%
import numpy as np
import sys
import time
# %matplotlib notebook
import matplotlib
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
plt.ion()
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import load_digits
import ipywidgets as widgets
from ipywidgets import interact, Play, IntSlider
from sklearn.decomposition import PCA

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.axes()
ax.scatter(np.random.randn(100), np.random.randn(100))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Population Gradient Descent
#
# The idea is to rethink gradient descent by running many small gradient descent processes in parallel, killing off the unsuccessful ones every so often and replacing them with "offspring" of the successful ones. It's evolutionary gradient descent. My guess is that it will perform worse in low dimensional spaces but better in high dimensional ones, where the chance that regular gradient descent finds a global optima is vanishingly small.
#
# Here's the procedure:
# 1. Set 100 Gaussian learners loose, each with a set mean, variance, and learning rate, which is from here on to be called a genome, denoted as $(\mu, \sigma^2, \alpha)$.
# 2. Run gradient descent for all 100 in parallel for 10 steps.
# 3. Cull 80% of the herd that occupies the worst positions
# 4. Reproduce each survivor 4 times each to seed a new herd
# 5. Go back to step 2 and repeat the process.
#
#
# The learners can be reproduced by sampling: sample the learner's Gaussian itself to get the new mean $\mu_{t+1}$, sample an Exponential distribution with the variance as the mean to get the new variance $\sigma^2_{t+1}$, and sample another Exponential with the learning rate as the mean to get the new learning rate $\alpha_{t+1}$.

# %% [markdown]
# We will learn parameters for some fully connected neural networks. The gradient descent steps will be implemented as batch gradient descent through backpropagation. In other words, each learner will be trained on the entire dataset 10 times. The main test will be to see how backpropagation as usual compares with PGD as the nets get deeper. My hypothesis is that PGD will start to perform better for nets beyond 3 or 4 layers deep.
#
# A key variable to keep an eye on is the learning rate for backpropagation. I need to make sure this is carefully optimized so that the comparison is fair, because in PGD the learners are allowed to evolve their own learning rate.

# %%
np.random.randn(*np.random.randn(4, 2).shape)
# Out:
# array([[ 0.22745993,  1.30714275],
#        [-1.60748323,  0.18463386],
#        [ 0.25988279,  0.78182287],
#        [-1.23695071, -1.32045661]])

# %%
class Individual(object):
    def __init__(self, learner_factory, stdev_init=1.0, learning_rate_init=0.1, *args, **kwargs):
        self.args = args
        self.kwargs = kwargs
        self.learner_factory = learner_factory
        self.learner = learner_factory(*args, **kwargs)
        self.stdev_init = stdev_init
        self.learning_rate_init = learning_rate_init
        self.means = self.learner.weights
        # self.stdevs = [np.ones(size=means.shape) * self.stdev_init for means in self.means]
        self.stdev = self.stdev_init
        self.learning_rate = self.learning_rate_init
    
    def clone(self):
        return Individual(self.learner_factory, stdev_init=self.stdev, learning_rate_init=self.learning_rate, *self.args, **self.kwargs)
    
    def reproduce(self, num=1):
        descendants = [self.clone() for i in range(num)]
        for child in descendants:
            child.means = [self.stdev * np.random.randn(*means.shape) + means for means in self.means]
            # child.stdevs = [np.random.exponential(scale=stdevs) for stdevs in self.stdevs]
            child.stdev = np.random.exponential(scale=self.stdev)
            child.learning_rate = np.random.exponential(scale=self.learning_rate)
        return descendants

    def fit(self, X, y):
        self.learner.weights = self.means
        # self.learner.num_epochs = 10
        self.learner.learning_rate = self.learning_rate
        self.learner.fit(X, y, transfer=True)
        # self.means = self.learner.weights
    
    def score(self, X, y, **kwargs):
        return self.learner.score(X, y, **kwargs)
        

class Population(object):
    def __init__(self, individual_factory=NeuralNetworkWithPCA, num=10, cull=0.8, num_generations=10, *args, **kwargs):
        self.population = [Individual(individual_factory, stdev_init=1, learning_rate_init=0.1, *args, **kwargs) for i in range(num)]
        self.num = num
        self.cull = cull
        self.num_generations = num_generations
        self.accuracy = np.zeros((self.num_generations))
        self.mse = np.zeros((self.num_generations))
        self.population_history = list(range(self.num_generations))
        for i in range(self.num_generations):
            self.population_history[i] = list(range(self.num))
    
    def _evolve(self, X, y, generation=None):
        for individual in self.population:
            individual.fit(X, y)
        
        if generation is not None:
            self.mse[generation] = np.mean([individual.score(X, y, metric='mse') for individual in self.population])
            self.accuracy[generation] = np.mean([individual.score(X, y, metric='accuracy') for individual in self.population])
            for i in range(self.num):
                self.population_history[generation][i] = [w.copy() for w in self.population[i].learner.weights]
        
        scores = [(i, self.population[i].score(X, y, metric='mse')**-1) for i in range(self.num)]
        scores.sort(key=lambda s: s[1])
        scores.reverse()
        self.population = [self.population[s[0]] for s in scores[:round(self.num*(1-self.cull))]]
        ind = 0
        initial_num = len(self.population)
        while len(self.population) < self.num:
            self.population.extend(self.population[ind].reproduce(num=1))
            ind = (ind + 1) % initial_num
    
    def fit(self, X, y):
        for i in range(self.num_generations):
            print("Fitting generation %d of %d" % (i, self.num_generations))
            self._evolve(X, y, generation=i)
    
    def score(self, X, y, metric='accuracy'):
        return [individual.score(X, y, metric=metric) for individual in self.population]

# %% [markdown]
# Note: interesting idea here for future exploration: evolve an individual learning rate for each weight parameter, so that deep ravines can be kind of broadened out by effectively rescaling the fast feature by slowing down the learning rate.

# %%
def sigmoid(X):
    return 1. / (1. + np.exp(-X))

def sigmoid_grad(X):
    return sigmoid(X) * ( 1 - sigmoid(X) )

def relu(X):
    return (X + np.abs(X)) / 2.

def relu_grad(X):
#     return relu(X) - relu(X-1)
    return sigmoid(X)

class NeuralNetworkWithPCA(object):
    def __init__(self, layers=(2,2,1), learning_rate=0.1, num_epochs=10, batch_size=None, activation='relu', use_pca=(True,True,)):
        self.num_layers = len(layers)
        self.layers = layers
        self.learning_rate = learning_rate
        self.num_epochs = num_epochs
        self.use_pca = use_pca
        self._batch_size_arg = batch_size
        
        self.nodes = list(range(self.num_layers))
        self.grad = list(range(self.num_layers))
        self.dw = list(range(self.num_layers-1))
        self.weights = list(range(self.num_layers-1))
        self.weights_history = list(range(self.num_layers-1))
        # self.nodes[0] = np.zeros(self.num_layers[0])
        for i in range(self.num_layers - 1):
            # self.nodes[i+1] = np.zeros(self.num_layers[i+1])
            self.weights[i] = np.random.randn(self.layers[i], self.layers[i+1])
            self.weights_history[i] = np.zeros((self.num_epochs+1, self.layers[i], self.layers[i+1]))
            self.weights_history[i][0] = self.weights[i]

        self.activation, self.activation_grad = self._activation_function(activation)
        self.accuracy = np.zeros((self.num_epochs))
        self.mse = np.zeros((self.num_epochs))
    
    def _initialise_pca(self, X):
        Xt = X.copy()
        for i in range(self.num_layers - 1):
            Xt = self._transform(Xt, layer=i)
            if self.use_pca[i]:                
                pca = PCA(n_components=self.layers[i+1])
                pca.fit(Xt)
                for j in range(self.layers[i+1]):
                    self.weights[i].T[j] = pca.components_[j]
    
    def _activation_function(self, name):
        funcs = {
            'relu': (relu, relu_grad),
            'sigmoid': (sigmoid, sigmoid_grad),
        }
        return funcs[name]
    
    def _metrics(self, name):
        funcs = {
            'accuracy': self._accuracy,
            'mse': self._mse,
        }
        return funcs[name]

    def _transform(self, X, layer=1):
        if layer == 0:
            return X
        return self.activation(np.dot(X, self.weights[layer-1]))
    
    def _transform_history(self, X, layer=1, epoch=None):
        epoch = self.num_epochs - 1 if epoch is None else epoch
        if layer == 0:
            return X
        return self.activation(np.dot(X, self.weights_history[layer-1][epoch]))
    
    def _cum_transform(self, X, layer=1):
        if layer > self.num_layers:
            raise Exception("There are only %d layers, but you specified the %dth layer" % (self.num_layers, layer))
        out = X
        for i in range(1, layer):
            out = self._transform(out, layer=i)
        return out
    
    def _forward(self, X):
        self.nodes[0] = X
        for i in range(1, self.num_layers):
            self.nodes[i] = self._transform(self.nodes[i-1], layer=i)
        self.output = self.nodes[self.num_layers-1]
        return self.output

    def _backward(self, X, y, epoch=None):
        n = X.shape[0]
        self._forward(X)
        error = y - self.output
        self.grad[self.num_layers-1] = error * self.activation_grad(self.output)
        for j in range(self.num_layers-2, -1, -1):
            self.grad[j] = np.dot(self.grad[j+1], self.weights[j].T) * self.activation_grad(self.nodes[j])
            self.dw[j] = np.dot(self.nodes[j].T, self.grad[j+1])
            self.weights[j] += self.learning_rate * self.dw[j] / n
            if epoch is not None:
                self.weights_history[j][epoch] = self.weights[j]

        correct = len([e for e in error if abs(e) < 0.5])
        accuracy = float(correct) / n
        mse = np.sum(np.square(error)) / n
        if epoch is not None:
            self.accuracy[epoch] = accuracy
            self.mse[epoch] = mse
        return accuracy, mse
            
    
    def fit(self, X, y, transfer=False):
        self.batch_size = round(self._batch_size_arg * X.shape[0]) if self._batch_size_arg is not None and self._batch_size_arg < 1 else self._batch_size_arg
        
        if not transfer and self.use_pca:
            self._initialise_pca(X)
        
        # start = time.time()
        # num_progress_bars = 20
        
        for i in range(self.num_epochs):
            if self.batch_size is not None:
                batch_idx = np.random.choice(np.arange(X.shape[0]), size=self.batch_size)
                B = X[batch_idx]
                yb = y[batch_idx]
            else:
                B = X
                yb = y
            
            accuracy, mse = self._backward(B, yb, epoch=i)

            # finish = time.time()
            # elapsed_time = float(time.time() - start)
            # progress = round(float(i)/self.num_epochs * num_progress_bars)
            
            # print("\r" + " "*80, end='\r')
            # print("\r" + ("Training Accuracy: " + str(round(accuracy, 3) * 100) + "% Time elapsed: " + str(round(elapsed_time, 2)) + "s |" + "="*(progress) + " "*(num_progress_bars-progress) + "|"), end='\r')
    
    def predict(self, X):
        return self.predict_proba(X)
    
    def predict_proba(self, X):
        return self._forward(X)
    
    def score(self, X, y, metric='accuracy', epoch=None):
        return self._metrics(metric)(X, y, epoch=epoch)
        
    def _accuracy(self, X, y, epoch=None, threshold=0.5):
        n = X.shape[0]
        output = self._forward_history(X, epoch=epoch)
        error = y - output
        correct = len([e for e in error if abs(e) < threshold])
        accuracy = float(correct) / n
        return accuracy
    
    def _mse(self, X, y, epoch=None):
        n = X.shape[0]
        output = self._forward_history(X, epoch=epoch)
        mse = (y - output)**2
        return np.sum(mse) / n
    
    def _forward_history(self, X, epoch=None):
        nodes = X
        for i in range(1, self.num_layers):
            nodes = self._transform_history(nodes, layer=i, epoch=epoch)
        output = nodes
        return output

# %%
def select_class(X, y, class_val=1):
    return np.array([X[i] for i in range(len(y)) if y[i] == class_val])

np.random.seed(42)
n = 100
d = 4
X = np.random.randn(n, d)
m = np.median(np.linalg.norm(X, axis=1))
y = np.array([1 if np.linalg.norm(x) >= m else 0 for x in X])
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, shuffle=True, random_state=42)

# X = relu(np.dot(X, np.random.randn(4,2)))
c0 = select_class(X, y, class_val=0)
c1 = select_class(X, y, class_val=1)
fig = plt.figure(figsize=(5,5))
ax = plt.axes()
ax.scatter(c0[:, 0], c0[:, 1], label='Class #0')
ax.scatter(c1[:, 0], c1[:, 1], label='Class #1')
ax.set_xlabel("$x_0$")
ax.set_ylabel("$x_1$")
ax.legend()
# Out:
# /Users/uniyomi/omi/miniconda3/envs/py3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# <img src="data:image/png;base64,..." width="500">

# %%
np.random.seed(42)
num_individuals = 20
num_epochs = 5
num_generations = 1000
cull = 0.75
batch_size = None
layers = (d, 2, 1)
use_pca = (False,False,)
population = Population(
    individual_factory=NeuralNetworkWithPCA,
    num=num_individuals,
    cull=cull,
    num_generations=num_generations,
    num_epochs=num_epochs,
    batch_size=batch_size,
    layers=layers,
    use_pca=use_pca,
)
population.fit(X_train, y_train[:, None])
# Out:
# Fitting generation 0 of 1000
# Fitting generation 1 of 1000
# Fitting generation 2 of 1000
# Fitting generation 3 of 1000
# Fitting generation 4 of 1000
# Fitting generation 5 of 1000
# Fitting generation 6 of 1000
# Fitting generation 7 of 1000
# Fitting generation 8 of 1000
# Fitting generation 9 of 1000
# Fitting generation 10 of 1000
# Fitting generation 11 of 1000
# Fitting generation 12 of 1000
# Fitting generation 13 of 1000
# Fitting generation 14 of 1000
# Fitting generation 15 of 1000
# Fitting generation 16 of 1000
# Fitting generation 17 of 1000
# Fitting generation 18 of 1000
# Fitting generation 19 of 1000
# Fitting generation 20 of 1000
# Fitting generation 21 of 1000
# Fitting generation 22 of 1000
# Fitting generation 23 of 1000
# Fitting generation 24 of 1000
# Fitting generation 25 of 1000
# Fitting generation 26 of 1000
# Fitting generation 27 of 1000
# Fitting generation 28 of 1000
# Fitting generation 29 of 1000
# Fitting generation 30 of 1000
# Fitting generation 31 of 1000
# Fitting generation 32 of 1000
# Fitting generation 33 of 1000
# Fitting generation 34 of 1000
# Fitting generation 35 of 1000
# Fitting generation 36 of 1000
# Fitting generation 37 of 1000
# Fitting generation 38 of 1000
# Fitting generation 39 of 1000
# Fitting generation 40 of 1000
# Fitting generation 41 of 1000
# Fitting generation 42 of 1000
# Fitting generation 43 of 1000
# Fitting generation 44 of 1000
# Fitting generation 45 of 1000
# Fitting generation 46 of 1000
# Fitting generation 47 of 1000
# Fitting generation 48 of 1000
# Fitting generation 49 of 1000
# Fitting generation 50 of 1000
# Fitting generation 51 of 1000
# Fitting generation 52 of 1000
# Fitting generation 53 of 1000
# Fitting generation 54 of 1000
# Fitting generation 55 of 1000
# Fitting generation 56 of 1000
# Fitting generation 57 of 1000
# Fitting generation 58 of 1000
# Fitting generation 59 of 1000
# Fitting generation 60 of 1000
# Fitting generation 61 of 1000
# Fitting generation 62 of 1000
# Fitting generation 63 of 1000
# Fitting generation 64 of 1000
# Fitting generation 65 of 1000
# Fitting generation 66 of 1000
# Fitting generation 67 of 1000
# Fitting generation 68 of 1000
# Fitting generation 69 of 1000
# Fitting generation 70 of 1000
# Fitting generation 71 of 1000
# Fitting generation 72 of 1000
# Fitting generation 73 of 1000
# Fitting generation 74 of 1000
# Fitting generation 75 of 1000
# Fitting generation 76 of 1000
# Fitting generation 77 of 1000
# Fitting generation 78 of 1000
# Fitting generation 79 of 1000
# Fitting generation 80 of 1000
# Fitting generation 81 of 1000
# Fitting generation 82 of 1000
# Fitting generation 83 of 1000
# Fitting generation 84 of 1000
# Fitting generation 85 of 1000
# Fitting generation 86 of 1000
# Fitting generation 87 of 1000
# Fitting generation 88 of 1000
# Fitting generation 89 of 1000
# Fitting generation 90 of 1000
# Fitting generation 91 of 1000
# Fitting generation 92 of 1000
# Fitting generation 93 of 1000
# Fitting generation 94 of 1000
# Fitting generation 95 of 1000
# Fitting generation 96 of 1000
# Fitting generation 97 of 1000
# Fitting generation 98 of 1000
# Fitting generation 99 of 1000
# Fitting generation 100 of 1000
# Fitting generation 101 of 1000
# Fitting generation 102 of 1000
# Fitting generation 103 of 1000
# Fitting generation 104 of 1000
# Fitting generation 105 of 1000
# Fitting generation 106 of 1000
# Fitting generation 107 of 1000
# Fitting generation 108 of 1000
# Fitting generation 109 of 1000
# Fitting generation 110 of 1000
# Fitting generation 111 of 1000
# Fitting generation 112 of 1000
# Fitting generation 113 of 1000
# Fitting generation 114 of 1000
# Fitting generation 115 of 1000
# Fitting generation 116 of 1000
# Fitting generation 117 of 1000
# Fitting generation 118 of 1000
# Fitting generation 119 of 1000
# Fitting generation 120 of 1000
# Fitting generation 121 of 1000
# Fitting generation 122 of 1000
# Fitting generation 123 of 1000
# Fitting generation 124 of 1000
# Fitting generation 125 of 1000
# Fitting generation 126 of 1000
# Fitting generation 127 of 1000
# Fitting generation 128 of 1000
# Fitting generation 129 of 1000
# Fitting generation 130 of 1000
# Fitting generation 131 of 1000
# Fitting generation 132 of 1000
# Fitting generation 133 of 1000
# Fitting generation 134 of 1000
# Fitting generation 135 of 1000
# Fitting generation 136 of 1000
# Fitting generation 137 of 1000
# Fitting generation 138 of 1000
# Fitting generation 139 of 1000
# Fitting generation 140 of 1000
# Fitting generation 141 of 1000
# Fitting generation 142 of 1000
# Fitting generation 143 of 1000
# Fitting generation 144 of 1000
# Fitting generation 145 of 1000
# Fitting generation 146 of 1000
# Fitting generation 147 of 1000
# Fitting generation 148 of 1000
# Fitting generation 149 of 1000
# Fitting generation 150 of 1000
# Fitting generation 151 of 1000
# Fitting generation 152 of 1000
# Fitting generation 153 of 1000
# Fitting generation 154 of 1000
# Fitting generation 155 of 1000
# Fitting generation 156 of 1000
# Fitting generation 157 of 1000
# Fitting generation 158 of 1000
# Fitting generation 159 of 1000
# Fitting generation 160 of 1000
# Fitting generation 161 of 1000
# Fitting generation 162 of 1000
# Fitting generation 163 of 1000
# Fitting generation 164 of 1000
# Fitting generation 165 of 1000
# Fitting generation 166 of 1000
# Fitting generation 167 of 1000
# Fitting generation 168 of 1000
# Fitting generation 169 of 1000
# Fitting generation 170 of 1000
# Fitting generation 171 of 1000
# Fitting generation 172 of 1000
# Fitting generation 173 of 1000
# Fitting generation 174 of 1000
# Fitting generation 175 of 1000
# Fitting generation 176 of 1000
# Fitting generation 177 of 1000
# Fitting generation 178 of 1000
# Fitting generation 179 of 1000
# Fitting generation 180 of 1000
# Fitting generation 181 of 1000
# Fitting generation 182 of 1000
# Fitting generation 183 of 1000
# Fitting generation 184 of 1000
# Fitting generation 185 of 1000
# Fitting generation 186 of 1000
# Fitting generation 187 of 1000
# Fitting generation 188 of 1000
# Fitting generation 189 of 1000
# Fitting generation 190 of 1000
# Fitting generation 191 of 1000
# Fitting generation 192 of 1000
# Fitting generation 193 of 1000
# Fitting generation 194 of 1000
# Fitting generation 195 of 1000
# Fitting generation 196 of 1000
# Fitting generation 197 of 1000
# Fitting generation 198 of 1000
# Fitting generation 199 of 1000
# Fitting generation 200 of 1000
# Fitting generation 201 of 1000
# Fitting generation 202 of 1000
# Fitting generation 203 of 1000
# Fitting generation 204 of 1000
# Fitting generation 205 of 1000
# Fitting generation 206 of 1000
# Fitting generation 207 of 1000
# Fitting generation 208 of 1000
# Fitting generation 209 of 1000
# Fitting generation 210 of 1000
# Fitting generation 211 of 1000
# Fitting generation 212 of 1000
# Fitting generation 213 of 1000
# Fitting generation 214 of 1000
# Fitting generation 215 of 1000
# Fitting generation 216 of 1000
# Fitting generation 217 of 1000
# Fitting generation 218 of 1000
# Fitting generation 219 of 1000
# Fitting generation 220 of 1000
# Fitting generation 221 of 1000
# Fitting generation 222 of 1000
# Fitting generation 223 of 1000
# Fitting generation 224 of 1000
# Fitting generation 225 of 1000
# Fitting generation 226 of 1000
# Fitting generation 227 of 1000
# Fitting generation 228 of 1000
# Fitting generation 229 of 1000
# Fitting generation 230 of 1000
# Fitting generation 231 of 1000
# Fitting generation 232 of 1000
# Fitting generation 233 of 1000
# Fitting generation 234 of 1000
# Fitting generation 235 of 1000
# Fitting generation 236 of 1000
# Fitting generation 237 of 1000
# Fitting generation 238 of 1000
# Fitting generation 239 of 1000
# Fitting generation 240 of 1000
# Fitting generation 241 of 1000
# Fitting generation 242 of 1000
# Fitting generation 243 of 1000
# Fitting generation 244 of 1000
# Fitting generation 245 of 1000
# Fitting generation 246 of 1000
# Fitting generation 247 of 1000
# Fitting generation 248 of 1000
# Fitting generation 249 of 1000
# Fitting generation 250 of 1000
# Fitting generation 251 of 1000
# Fitting generation 252 of 1000
# Fitting generation 253 of 1000
# Fitting generation 254 of 1000
# Fitting generation 255 of 1000
# Fitting generation 256 of 1000
# Fitting generation 257 of 1000
# Fitting generation 258 of 1000
# Fitting generation 259 of 1000
# Fitting generation 260 of 1000
# Fitting generation 261 of 1000
# Fitting generation 262 of 1000
# Fitting generation 263 of 1000
# Fitting generation 264 of 1000
# Fitting generation 265 of 1000
# Fitting generation 266 of 1000
# Fitting generation 267 of 1000
# Fitting generation 268 of 1000
# Fitting generation 269 of 1000
# Fitting generation 270 of 1000
# Fitting generation 271 of 1000
# Fitting generation 272 of 1000
# Fitting generation 273 of 1000
# Fitting generation 274 of 1000
# Fitting generation 275 of 1000
# Fitting generation 276 of 1000
# Fitting generation 277 of 1000
# Fitting generation 278 of 1000
# Fitting generation 279 of 1000
# Fitting generation 280 of 1000
# Fitting generation 281 of 1000
# Fitting generation 282 of 1000
# Fitting generation 283 of 1000
# Fitting generation 284 of 1000
# Fitting generation 285 of 1000
# Fitting generation 286 of 1000
# Fitting generation 287 of 1000
# Fitting generation 288 of 1000
# Fitting generation 289 of 1000
# Fitting generation 290 of 1000
# Fitting generation 291 of 1000
# Fitting generation 292 of 1000
# Fitting generation 293 of 1000
# Fitting generation 294 of 1000
# Fitting generation 295 of 1000
# Fitting generation 296 of 1000
# Fitting generation 297 of 1000
# Fitting generation 298 of 1000
# Fitting generation 299 of 1000
# Fitting generation 300 of 1000
# Fitting generation 301 of 1000
# Fitting generation 302 of 1000
# Fitting generation 303 of 1000
# Fitting generation 304 of 1000
# Fitting generation 305 of 1000
# Fitting generation 306 of 1000
# Fitting generation 307 of 1000
# Fitting generation 308 of 1000
# Fitting generation 309 of 1000
# Fitting generation 310 of 1000
# Fitting generation 311 of 1000
# Fitting generation 312 of 1000
# Fitting generation 313 of 1000
# Fitting generation 314 of 1000
# Fitting generation 315 of 1000
# Fitting generation 316 of 1000
# Fitting generation 317 of 1000
# Fitting generation 318 of 1000
# Fitting generation 319 of 1000
# Fitting generation 320 of 1000
# Fitting generation 321 of 1000
# Fitting generation 322 of 1000
# Fitting generation 323 of 1000
# Fitting generation 324 of 1000
# Fitting generation 325 of 1000
# Fitting generation 326 of 1000
# Fitting generation 327 of 1000
# Fitting generation 328 of 1000
# Fitting generation 329 of 1000
# Fitting generation 330 of 1000
# Fitting generation 331 of 1000
# Fitting generation 332 of 1000
# Fitting generation 333 of 1000
# Fitting generation 334 of 1000
# Fitting generation 335 of 1000
# Fitting generation 336 of 1000
# Fitting generation 337 of 1000
# Fitting generation 338 of 1000
# Fitting generation 339 of 1000
# Fitting generation 340 of 1000
# Fitting generation 341 of 1000
# Fitting generation 342 of 1000
# Fitting generation 343 of 1000
# Fitting generation 344 of 1000
# Fitting generation 345 of 1000
# Fitting generation 346 of 1000
# Fitting generation 347 of 1000
# Fitting generation 348 of 1000
# Fitting generation 349 of 1000
# Fitting generation 350 of 1000
# Fitting generation 351 of 1000
# Fitting generation 352 of 1000
# Fitting generation 353 of 1000
# Fitting generation 354 of 1000
# Fitting generation 355 of 1000
# Fitting generation 356 of 1000
# Fitting generation 357 of 1000
# Fitting generation 358 of 1000
# Fitting generation 359 of 1000
# Fitting generation 360 of 1000
# Fitting generation 361 of 1000
# Fitting generation 362 of 1000
# Fitting generation 363 of 1000
# Fitting generation 364 of 1000
# Fitting generation 365 of 1000
# Fitting generation 366 of 1000
# Fitting generation 367 of 1000
# Fitting generation 368 of 1000
# Fitting generation 369 of 1000
# Fitting generation 370 of 1000
# Fitting generation 371 of 1000
# Fitting generation 372 of 1000
# Fitting generation 373 of 1000
# Fitting generation 374 of 1000
# Fitting generation 375 of 1000
# Fitting generation 376 of 1000
# Fitting generation 377 of 1000
# Fitting generation 378 of 1000
# Fitting generation 379 of 1000
# Fitting generation 380 of 1000
# Fitting generation 381 of 1000
# Fitting generation 382 of 1000
# Fitting generation 383 of 1000
# Fitting generation 384 of 1000
# Fitting generation 385 of 1000
# Fitting generation 386 of 1000
# Fitting generation 387 of 1000
# Fitting generation 388 of 1000
# Fitting generation 389 of 1000
# Fitting generation 390 of 1000
# Fitting generation 391 of 1000
# Fitting generation 392 of 1000
# Fitting generation 393 of 1000
# Fitting generation 394 of 1000
# Fitting generation 395 of 1000
# Fitting generation 396 of 1000
# Fitting generation 397 of 1000
# Fitting generation 398 of 1000
# Fitting generation 399 of 1000
# Fitting generation 400 of 1000
# Fitting generation 401 of 1000
# Fitting generation 402 of 1000
# Fitting generation 403 of 1000
# Fitting generation 404 of 1000
# Fitting generation 405 of 1000
# Fitting generation 406 of 1000
# Fitting generation 407 of 1000
# Fitting generation 408 of 1000
# Fitting generation 409 of 1000
# Fitting generation 410 of 1000
# Fitting generation 411 of 1000
# Fitting generation 412 of 1000
# Fitting generation 413 of 1000
# Fitting generation 414 of 1000
# Fitting generation 415 of 1000
# Fitting generation 416 of 1000
# Fitting generation 417 of 1000
# Fitting generation 418 of 1000
# Fitting generation 419 of 1000
# Fitting generation 420 of 1000
# Fitting generation 421 of 1000
# Fitting generation 422 of 1000
# Fitting generation 423 of 1000
# Fitting generation 424 of 1000
# Fitting generation 425 of 1000
# Fitting generation 426 of 1000
# Fitting generation 427 of 1000
# Fitting generation 428 of 1000
# Fitting generation 429 of 1000
# Fitting generation 430 of 1000
# Fitting generation 431 of 1000
# Fitting generation 432 of 1000
# Fitting generation 433 of 1000
# Fitting generation 434 of 1000
# Fitting generation 435 of 1000
# Fitting generation 436 of 1000
# Fitting generation 437 of 1000
# Fitting generation 438 of 1000
# Fitting generation 439 of 1000
# Fitting generation 440 of 1000
# Fitting generation 441 of 1000
# Fitting generation 442 of 1000
# Fitting generation 443 of 1000
# Fitting generation 444 of 1000
# Fitting generation 445 of 1000
# Fitting generation 446 of 1000
# Fitting generation 447 of 1000
# Fitting generation 448 of 1000
# Fitting generation 449 of 1000
# Fitting generation 450 of 1000
# Fitting generation 451 of 1000
# Fitting generation 452 of 1000
# Fitting generation 453 of 1000
# Fitting generation 454 of 1000
# Fitting generation 455 of 1000
# Fitting generation 456 of 1000
# Fitting generation 457 of 1000
# Fitting generation 458 of 1000
# Fitting generation 459 of 1000
# Fitting generation 460 of 1000
# Fitting generation 461 of 1000
# Fitting generation 462 of 1000
# Fitting generation 463 of 1000
# Fitting generation 464 of 1000
# Fitting generation 465 of 1000
# Fitting generation 466 of 1000
# Fitting generation 467 of 1000
# Fitting generation 468 of 1000
# Fitting generation 469 of 1000
# Fitting generation 470 of 1000
# Fitting generation 471 of 1000
# Fitting generation 472 of 1000
# Fitting generation 473 of 1000
# Fitting generation 474 of 1000
# Fitting generation 475 of 1000
# Fitting generation 476 of 1000
# Fitting generation 477 of 1000
# Fitting generation 478 of 1000
# Fitting generation 479 of 1000
# Fitting generation 480 of 1000
# Fitting generation 481 of 1000
# Fitting generation 482 of 1000
# Fitting generation 483 of 1000
# Fitting generation 484 of 1000
# Fitting generation 485 of 1000
# Fitting generation 486 of 1000
# Fitting generation 487 of 1000
# Fitting generation 488 of 1000
# Fitting generation 489 of 1000
# Fitting generation 490 of 1000
# Fitting generation 491 of 1000
# Fitting generation 492 of 1000
# Fitting generation 493 of 1000
# Fitting generation 494 of 1000
# Fitting generation 495 of 1000
# Fitting generation 496 of 1000
# Fitting generation 497 of 1000
# Fitting generation 498 of 1000
# Fitting generation 499 of 1000
# Fitting generation 500 of 1000
# Fitting generation 501 of 1000
# Fitting generation 502 of 1000
# Fitting generation 503 of 1000
# Fitting generation 504 of 1000
# Fitting generation 505 of 1000
# Fitting generation 506 of 1000
# Fitting generation 507 of 1000
# Fitting generation 508 of 1000
# Fitting generation 509 of 1000
# Fitting generation 510 of 1000
# Fitting generation 511 of 1000
# Fitting generation 512 of 1000
# Fitting generation 513 of 1000
# Fitting generation 514 of 1000
# Fitting generation 515 of 1000
# Fitting generation 516 of 1000
# Fitting generation 517 of 1000
# Fitting generation 518 of 1000
# Fitting generation 519 of 1000
# Fitting generation 520 of 1000
# Fitting generation 521 of 1000
# Fitting generation 522 of 1000
# Fitting generation 523 of 1000
# Fitting generation 524 of 1000
# Fitting generation 525 of 1000
# Fitting generation 526 of 1000
# Fitting generation 527 of 1000
# Fitting generation 528 of 1000
# Fitting generation 529 of 1000
# Fitting generation 530 of 1000
# Fitting generation 531 of 1000
# Fitting generation 532 of 1000
# Fitting generation 533 of 1000
# Fitting generation 534 of 1000
# Fitting generation 535 of 1000
# Fitting generation 536 of 1000
# Fitting generation 537 of 1000
# Fitting generation 538 of 1000
# Fitting generation 539 of 1000
# Fitting generation 540 of 1000
# Fitting generation 541 of 1000
# Fitting generation 542 of 1000
# Fitting generation 543 of 1000
# Fitting generation 544 of 1000
# Fitting generation 545 of 1000
# Fitting generation 546 of 1000
# Fitting generation 547 of 1000
# Fitting generation 548 of 1000
# Fitting generation 549 of 1000
# Fitting generation 550 of 1000
# Fitting generation 551 of 1000
# Fitting generation 552 of 1000
# Fitting generation 553 of 1000
# Fitting generation 554 of 1000
# Fitting generation 555 of 1000
# Fitting generation 556 of 1000
# Fitting generation 557 of 1000
# Fitting generation 558 of 1000
# Fitting generation 559 of 1000
# Fitting generation 560 of 1000
# Fitting generation 561 of 1000
# Fitting generation 562 of 1000
# Fitting generation 563 of 1000
# Fitting generation 564 of 1000
# Fitting generation 565 of 1000
# Fitting generation 566 of 1000
# Fitting generation 567 of 1000
# Fitting generation 568 of 1000
# Fitting generation 569 of 1000
# Fitting generation 570 of 1000
# Fitting generation 571 of 1000
# Fitting generation 572 of 1000
# Fitting generation 573 of 1000
# Fitting generation 574 of 1000
# Fitting generation 575 of 1000
# Fitting generation 576 of 1000
# Fitting generation 577 of 1000
# Fitting generation 578 of 1000
# Fitting generation 579 of 1000
# Fitting generation 580 of 1000
# Fitting generation 581 of 1000
# Fitting generation 582 of 1000
# Fitting generation 583 of 1000
# Fitting generation 584 of 1000
# Fitting generation 585 of 1000
# Fitting generation 586 of 1000
# Fitting generation 587 of 1000
# Fitting generation 588 of 1000
# Fitting generation 589 of 1000
# Fitting generation 590 of 1000
# Fitting generation 591 of 1000
# Fitting generation 592 of 1000
# Fitting generation 593 of 1000
# Fitting generation 594 of 1000
# Fitting generation 595 of 1000
# Fitting generation 596 of 1000
# Fitting generation 597 of 1000
# Fitting generation 598 of 1000
# Fitting generation 599 of 1000
# Fitting generation 600 of 1000
# Fitting generation 601 of 1000
# Fitting generation 602 of 1000
# Fitting generation 603 of 1000
# Fitting generation 604 of 1000
# Fitting generation 605 of 1000
# Fitting generation 606 of 1000
# Fitting generation 607 of 1000
# Fitting generation 608 of 1000
# Fitting generation 609 of 1000
# Fitting generation 610 of 1000
# Fitting generation 611 of 1000
# Fitting generation 612 of 1000
# Fitting generation 613 of 1000
# Fitting generation 614 of 1000
# Fitting generation 615 of 1000
# Fitting generation 616 of 1000
# Fitting generation 617 of 1000
# Fitting generation 618 of 1000
# Fitting generation 619 of 1000
# Fitting generation 620 of 1000
# Fitting generation 621 of 1000
# Fitting generation 622 of 1000
# Fitting generation 623 of 1000
# Fitting generation 624 of 1000
# Fitting generation 625 of 1000
# Fitting generation 626 of 1000
# Fitting generation 627 of 1000
# Fitting generation 628 of 1000
# Fitting generation 629 of 1000
# Fitting generation 630 of 1000
# Fitting generation 631 of 1000
# Fitting generation 632 of 1000
# Fitting generation 633 of 1000
# Fitting generation 634 of 1000
# Fitting generation 635 of 1000
# Fitting generation 636 of 1000
# Fitting generation 637 of 1000
# Fitting generation 638 of 1000
# Fitting generation 639 of 1000
# Fitting generation 640 of 1000
# Fitting generation 641 of 1000
# Fitting generation 642 of 1000
# Fitting generation 643 of 1000
# Fitting generation 644 of 1000
# Fitting generation 645 of 1000
# Fitting generation 646 of 1000
# Fitting generation 647 of 1000
# Fitting generation 648 of 1000
# Fitting generation 649 of 1000
# Fitting generation 650 of 1000
# Fitting generation 651 of 1000
# Fitting generation 652 of 1000
# Fitting generation 653 of 1000
# Fitting generation 654 of 1000
# Fitting generation 655 of 1000
# Fitting generation 656 of 1000
# Fitting generation 657 of 1000
# Fitting generation 658 of 1000
# Fitting generation 659 of 1000
# Fitting generation 660 of 1000
# Fitting generation 661 of 1000
# Fitting generation 662 of 1000
# Fitting generation 663 of 1000
# Fitting generation 664 of 1000
# Fitting generation 665 of 1000
# Fitting generation 666 of 1000
# Fitting generation 667 of 1000
# Fitting generation 668 of 1000
# Fitting generation 669 of 1000
# Fitting generation 670 of 1000
# Fitting generation 671 of 1000
# Fitting generation 672 of 1000
# Fitting generation 673 of 1000
# Fitting generation 674 of 1000
# Fitting generation 675 of 1000
# Fitting generation 676 of 1000
# Fitting generation 677 of 1000
# Fitting generation 678 of 1000
# Fitting generation 679 of 1000
# Fitting generation 680 of 1000
# Fitting generation 681 of 1000
# Fitting generation 682 of 1000
# Fitting generation 683 of 1000
# Fitting generation 684 of 1000
# Fitting generation 685 of 1000
# Fitting generation 686 of 1000
# Fitting generation 687 of 1000
# Fitting generation 688 of 1000
# Fitting generation 689 of 1000
# Fitting generation 690 of 1000
# Fitting generation 691 of 1000
# Fitting generation 692 of 1000
# Fitting generation 693 of 1000
# Fitting generation 694 of 1000
# Fitting generation 695 of 1000
# Fitting generation 696 of 1000
# Fitting generation 697 of 1000
# Fitting generation 698 of 1000
# Fitting generation 699 of 1000
# Fitting generation 700 of 1000
# Fitting generation 701 of 1000
# Fitting generation 702 of 1000
# Fitting generation 703 of 1000
# Fitting generation 704 of 1000
# Fitting generation 705 of 1000
# Fitting generation 706 of 1000
# Fitting generation 707 of 1000
# Fitting generation 708 of 1000
# Fitting generation 709 of 1000
# Fitting generation 710 of 1000
# Fitting generation 711 of 1000
# Fitting generation 712 of 1000
# Fitting generation 713 of 1000
# Fitting generation 714 of 1000
# Fitting generation 715 of 1000
# Fitting generation 716 of 1000
# Fitting generation 717 of 1000
# Fitting generation 718 of 1000
# Fitting generation 719 of 1000
# Fitting generation 720 of 1000
# Fitting generation 721 of 1000
# Fitting generation 722 of 1000
# Fitting generation 723 of 1000
# Fitting generation 724 of 1000
# Fitting generation 725 of 1000
# Fitting generation 726 of 1000
# Fitting generation 727 of 1000
# Fitting generation 728 of 1000
# Fitting generation 729 of 1000
# Fitting generation 730 of 1000
# Fitting generation 731 of 1000
# Fitting generation 732 of 1000
# Fitting generation 733 of 1000
# Fitting generation 734 of 1000
# Fitting generation 735 of 1000
# Fitting generation 736 of 1000
# Fitting generation 737 of 1000
# Fitting generation 738 of 1000
# Fitting generation 739 of 1000
# Fitting generation 740 of 1000
# Fitting generation 741 of 1000
# Fitting generation 742 of 1000
# Fitting generation 743 of 1000
# Fitting generation 744 of 1000
# Fitting generation 745 of 1000
# Fitting generation 746 of 1000
# Fitting generation 747 of 1000
# Fitting generation 748 of 1000
# Fitting generation 749 of 1000
# Fitting generation 750 of 1000
# Fitting generation 751 of 1000
# Fitting generation 752 of 1000
# Fitting generation 753 of 1000
# Fitting generation 754 of 1000
# Fitting generation 755 of 1000
# Fitting generation 756 of 1000
# Fitting generation 757 of 1000
# Fitting generation 758 of 1000
# Fitting generation 759 of 1000
# Fitting generation 760 of 1000
# Fitting generation 761 of 1000
# Fitting generation 762 of 1000
# Fitting generation 763 of 1000
# Fitting generation 764 of 1000
# Fitting generation 765 of 1000
# Fitting generation 766 of 1000
# Fitting generation 767 of 1000
# Fitting generation 768 of 1000
# Fitting generation 769 of 1000
# Fitting generation 770 of 1000
# Fitting generation 771 of 1000
# Fitting generation 772 of 1000
# Fitting generation 773 of 1000
# Fitting generation 774 of 1000
# Fitting generation 775 of 1000
# Fitting generation 776 of 1000
# Fitting generation 777 of 1000
# Fitting generation 778 of 1000
# Fitting generation 779 of 1000
# Fitting generation 780 of 1000
# Fitting generation 781 of 1000
# Fitting generation 782 of 1000
# Fitting generation 783 of 1000
# Fitting generation 784 of 1000
# Fitting generation 785 of 1000
# Fitting generation 786 of 1000
# Fitting generation 787 of 1000
# Fitting generation 788 of 1000
# Fitting generation 789 of 1000
# Fitting generation 790 of 1000
# Fitting generation 791 of 1000
# Fitting generation 792 of 1000
# Fitting generation 793 of 1000
# Fitting generation 794 of 1000
# Fitting generation 795 of 1000
# Fitting generation 796 of 1000
# Fitting generation 797 of 1000
# Fitting generation 798 of 1000
# Fitting generation 799 of 1000
# Fitting generation 800 of 1000
# Fitting generation 801 of 1000
# Fitting generation 802 of 1000
# Fitting generation 803 of 1000
# Fitting generation 804 of 1000
# Fitting generation 805 of 1000
# Fitting generation 806 of 1000
# Fitting generation 807 of 1000
# Fitting generation 808 of 1000
# Fitting generation 809 of 1000
# Fitting generation 810 of 1000
# Fitting generation 811 of 1000
# Fitting generation 812 of 1000
# Fitting generation 813 of 1000
# Fitting generation 814 of 1000
# Fitting generation 815 of 1000
# Fitting generation 816 of 1000
# Fitting generation 817 of 1000
# Fitting generation 818 of 1000
# Fitting generation 819 of 1000
# Fitting generation 820 of 1000
# Fitting generation 821 of 1000
# Fitting generation 822 of 1000
# Fitting generation 823 of 1000
# Fitting generation 824 of 1000
# Fitting generation 825 of 1000
# Fitting generation 826 of 1000
# Fitting generation 827 of 1000
# Fitting generation 828 of 1000
# Fitting generation 829 of 1000
# Fitting generation 830 of 1000
# Fitting generation 831 of 1000
# Fitting generation 832 of 1000
# Fitting generation 833 of 1000
# Fitting generation 834 of 1000
# Fitting generation 835 of 1000
# Fitting generation 836 of 1000
# Fitting generation 837 of 1000
# Fitting generation 838 of 1000
# Fitting generation 839 of 1000
# Fitting generation 840 of 1000
# Fitting generation 841 of 1000
# Fitting generation 842 of 1000
# Fitting generation 843 of 1000
# Fitting generation 844 of 1000
# Fitting generation 845 of 1000
# Fitting generation 846 of 1000
# Fitting generation 847 of 1000
# Fitting generation 848 of 1000
# Fitting generation 849 of 1000
# Fitting generation 850 of 1000
# Fitting generation 851 of 1000
# Fitting generation 852 of 1000
# Fitting generation 853 of 1000
# Fitting generation 854 of 1000
# Fitting generation 855 of 1000
# Fitting generation 856 of 1000
# Fitting generation 857 of 1000
# Fitting generation 858 of 1000
# Fitting generation 859 of 1000
# Fitting generation 860 of 1000
# Fitting generation 861 of 1000
# Fitting generation 862 of 1000
# Fitting generation 863 of 1000
# Fitting generation 864 of 1000
# Fitting generation 865 of 1000
# Fitting generation 866 of 1000
# Fitting generation 867 of 1000
# Fitting generation 868 of 1000
# Fitting generation 869 of 1000
# Fitting generation 870 of 1000
# Fitting generation 871 of 1000
# Fitting generation 872 of 1000
# Fitting generation 873 of 1000
# Fitting generation 874 of 1000
# Fitting generation 875 of 1000
# Fitting generation 876 of 1000
# Fitting generation 877 of 1000
# Fitting generation 878 of 1000
# Fitting generation 879 of 1000
# Fitting generation 880 of 1000
# Fitting generation 881 of 1000
# Fitting generation 882 of 1000
# Fitting generation 883 of 1000
# Fitting generation 884 of 1000
# Fitting generation 885 of 1000
# Fitting generation 886 of 1000
# Fitting generation 887 of 1000
# Fitting generation 888 of 1000
# Fitting generation 889 of 1000
# Fitting generation 890 of 1000
# Fitting generation 891 of 1000
# Fitting generation 892 of 1000
# Fitting generation 893 of 1000
# Fitting generation 894 of 1000
# Fitting generation 895 of 1000
# Fitting generation 896 of 1000
# Fitting generation 897 of 1000
# Fitting generation 898 of 1000
# Fitting generation 899 of 1000
# Fitting generation 900 of 1000
# Fitting generation 901 of 1000
# Fitting generation 902 of 1000
# Fitting generation 903 of 1000
# Fitting generation 904 of 1000
# Fitting generation 905 of 1000
# Fitting generation 906 of 1000
# Fitting generation 907 of 1000
# Fitting generation 908 of 1000
# Fitting generation 909 of 1000
# Fitting generation 910 of 1000
# Fitting generation 911 of 1000
# Fitting generation 912 of 1000
# Fitting generation 913 of 1000
# Fitting generation 914 of 1000
# Fitting generation 915 of 1000
# Fitting generation 916 of 1000
# Fitting generation 917 of 1000
# Fitting generation 918 of 1000
# Fitting generation 919 of 1000
# Fitting generation 920 of 1000
# Fitting generation 921 of 1000
# Fitting generation 922 of 1000
# Fitting generation 923 of 1000
# Fitting generation 924 of 1000
# Fitting generation 925 of 1000
# Fitting generation 926 of 1000
# Fitting generation 927 of 1000
# Fitting generation 928 of 1000
# Fitting generation 929 of 1000
# Fitting generation 930 of 1000
# Fitting generation 931 of 1000
# Fitting generation 932 of 1000
# Fitting generation 933 of 1000
# Fitting generation 934 of 1000
# Fitting generation 935 of 1000
# Fitting generation 936 of 1000
# Fitting generation 937 of 1000
# Fitting generation 938 of 1000
# Fitting generation 939 of 1000
# Fitting generation 940 of 1000
# Fitting generation 941 of 1000
# Fitting generation 942 of 1000
# Fitting generation 943 of 1000
# Fitting generation 944 of 1000
# Fitting generation 945 of 1000
# Fitting generation 946 of 1000
# Fitting generation 947 of 1000
# Fitting generation 948 of 1000
# Fitting generation 949 of 1000
# Fitting generation 950 of 1000
# Fitting generation 951 of 1000
# Fitting generation 952 of 1000
# Fitting generation 953 of 1000
# Fitting generation 954 of 1000
# Fitting generation 955 of 1000
# Fitting generation 956 of 1000
# Fitting generation 957 of 1000
# Fitting generation 958 of 1000
# Fitting generation 959 of 1000
# Fitting generation 960 of 1000
# Fitting generation 961 of 1000
# Fitting generation 962 of 1000
# Fitting generation 963 of 1000
# Fitting generation 964 of 1000
# Fitting generation 965 of 1000
# Fitting generation 966 of 1000
# Fitting generation 967 of 1000
# Fitting generation 968 of 1000
# Fitting generation 969 of 1000
# Fitting generation 970 of 1000
# Fitting generation 971 of 1000
# Fitting generation 972 of 1000
# Fitting generation 973 of 1000
# Fitting generation 974 of 1000
# Fitting generation 975 of 1000
# Fitting generation 976 of 1000
# Fitting generation 977 of 1000
# Fitting generation 978 of 1000
# Fitting generation 979 of 1000
# Fitting generation 980 of 1000
# Fitting generation 981 of 1000
# Fitting generation 982 of 1000
# Fitting generation 983 of 1000
# Fitting generation 984 of 1000
# Fitting generation 985 of 1000
# Fitting generation 986 of 1000
# Fitting generation 987 of 1000
# Fitting generation 988 of 1000
# Fitting generation 989 of 1000
# Fitting generation 990 of 1000
# Fitting generation 991 of 1000
# Fitting generation 992 of 1000
# Fitting generation 993 of 1000
# Fitting generation 994 of 1000
# Fitting generation 995 of 1000
# Fitting generation 996 of 1000
# Fitting generation 997 of 1000
# Fitting generation 998 of 1000
# Fitting generation 999 of 1000

# %%
population.score(X_test, y_test[:, None])
# Out:
# [0.64,
#  0.64,
#  0.64,
#  0.64,
#  0.64,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48,
#  0.48]

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax.plot(np.array(population.mse)**-1)
ax2.plot(population.accuracy)
# for i in population.population:
#     nn = i.learner
#     ax.plot(nn.mse**-1)
#     ax2.plot(nn.accuracy)
ax.set_xlabel("Generation")
ax2.set_xlabel("Generation")
ax.set_ylabel("Average MSE$^-1$")
ax2.set_ylabel("Average accuracy (%)")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0,0.5,'Average accuracy (%)')

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)

ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

max_gen = min(num_generations-1, 500)

# @interact(generation=(0, num_generations-1))
generations = Play(interval=100,value=0,min=0,max=max_gen,step=1)
slider = IntSlider(value=0,min=0,max=max_gen,step=1)
widgets.jslink((generations, 'value'), (slider, 'value'))
# @interact(generation=generations)
def update(generation):
    layer = 0
    lookback = 5
    ax.cla()
    ax2.cla()
    ax.grid()
    ax2.grid()
    for i in range(lookback):
        if generation - i >= 0:
            h = population.population_history[generation - i]
            w0 = np.array([w[layer][0] for w in h])
            w1 = np.array([w[layer][1] for w in h])
            alpha = 1-i/lookback
            ax.scatter(w0[:,0], w0[:,1], color='C0', s=3, alpha=alpha)
            ax2.scatter(w1[:,0], w1[:,1], color='C0', s=3, alpha=alpha)
    ax.set_xbound(lower=-1,upper=1)
    ax.set_ybound(lower=-1,upper=1)
    ax2.set_xbound(lower=-1,upper=1)
    ax2.set_ybound(lower=-1,upper=1)
    
    ax3.cla()
    ax4.cla()
    ax3.plot((population.mse**-1)[:max_gen])
    ax3.scatter(generation, (population.mse**-1)[generation])
    ax4.plot(population.accuracy[:max_gen])
    ax4.scatter(generation, population.accuracy[generation])

out = widgets.interactive_output(update, {'generation': generations})
display(widgets.HBox([generations, slider]))
# Out:
# <img src="data:image/png;base64,..." width="900">
# HBox(children=(Play(value=0, max=500), IntSlider(value=0, max=500)))

# %%
h = population.population_history[500]

# %%
h
# Out:
# [[array([[ 1.64233573, -0.1291425 ],
#          [-2.03306887,  0.15843375]]), array([[ 0.25812163],
#          [ 2.90911822]])], [array([[ 1.64236336, -0.12911766],
#          [-2.03315288,  0.15847127]]), array([[ 0.25804961],
#          [ 2.90919455]])], [array([[ 1.64236569, -0.129118  ],
#          [-2.03315128,  0.15847843]]), array([[ 0.25805401],
#          [ 2.90919899]])], [array([[ 1.64236507, -0.12911999],
#          [-2.03315574,  0.15847482]]), array([[ 0.2580487 ],
#          [ 2.90919488]])], [array([[ 1.64236079, -0.12911462],
#          [-2.03315533,  0.15847509]]), array([[ 0.25804804],
#          [ 2.9091935 ]])], [array([[ 1.6424358 , -0.12918342],
#          [-2.03269833,  0.15888766]]), array([[ 0.25838678],
#          [ 2.90927489]])], [array([[ 1.64236383, -0.12911738],
#          [-2.03315349,  0.15847115]]), array([[ 0.25804935],
#          [ 2.9091954 ]])], [array([[ 1.6423673 , -0.12912236],
#          [-2.03315   ,  0.15848319]]), array([[ 0.2580467],
#          [ 2.9091943]])], [array([[ 1.6423656 , -0.12911922],
#          [-2.0331562 ,  0.15847347]]), array([[ 0.25804787],
#          [ 2.90919655]])], [array([[ 1.64236154, -0.12911388],
#          [-2.03315597,  0.1584754 ]]), array([[ 0.25804788],
#          [ 2.90919402]])], [array([[ 1.64218827, -0.12929396],
#          [-2.03317194,  0.15829215]]), array([[ 0.25816904],
#          [ 2.90903788]])], [array([[ 1.64236375, -0.12911647],
#          [-2.0331533 ,  0.158471  ]]), array([[ 0.2580504 ],
#          [ 2.90919452]])], [array([[ 1.64235272, -0.1291261 ],
#          [-2.03314521,  0.15848217]]), array([[ 0.25806193],
#          [ 2.90920028]])], [array([[ 1.6423645 , -0.12911897],
#          [-2.03315572,  0.15847345]]), array([[ 0.25804912],
#          [ 2.90919483]])], [array([[ 1.64236182, -0.12911474],
#          [-2.0331549 ,  0.15847568]]), array([[ 0.25804808],
#          [ 2.90919361]])], [array([[ 1.6425586 , -0.12936453],
#          [-2.03313705,  0.15823353]]), array([[ 0.25827473],
#          [ 2.90942176]])], [array([[ 1.64236248, -0.12911891],
#          [-2.03315268,  0.15847105]]), array([[ 0.25805009],
#          [ 2.90919553]])], [array([[ 1.6423721 , -0.12912657],
#          [-2.03314796,  0.15847347]]), array([[ 0.25804398],
#          [ 2.90920116]])], [array([[ 1.64236569, -0.1291206 ],
#          [-2.03315599,  0.15847362]]), array([[ 0.25804933],
#          [ 2.90919421]])], [array([[ 1.64236134, -0.12911451],
#          [-2.03315534,  0.1584751 ]]), array([[ 0.25804857],
#          [ 2.90919331]])]]

# %%
w
# Out:
# array([[ 1.64233573, -0.1291425 ],
#        [ 1.64236336, -0.12911766],
#        [ 1.64236569, -0.129118  ],
#        [ 1.64236507, -0.12911999],
#        [ 1.64236079, -0.12911462],
#        [ 1.6424358 , -0.12918342],
#        [ 1.64236383, -0.12911738],
#        [ 1.6423673 , -0.12912236],
#        [ 1.6423656 , -0.12911922],
#        [ 1.64236154, -0.12911388],
#        [ 1.64218827, -0.12929396],
#        [ 1.64236375, -0.12911647],
#        [ 1.64235272, -0.1291261 ],
#        [ 1.6423645 , -0.12911897],
#        [ 1.64236182, -0.12911474],
#        [ 1.6425586 , -0.12936453],
#        [ 1.64236248, -0.12911891],
#        [ 1.6423721 , -0.12912657],
#        [ 1.64236569, -0.1291206 ],
#        [ 1.64236134, -0.12911451]])

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.axes()
activation = relu
layer = 0
@interact(generation=(0,population.num_generations-1))
def update(generation):
    best_weights = population.population_history[generation][0]
    xt = activation(np.dot(X, best_weights[layer]))
#     xt = np.dot(X, best_weights[layer])
    xt0 = select_class(xt, y, class_val=0)
    xt1 = select_class(xt, y, class_val=1)
    ax.cla()
    ax.scatter(xt0[:,0], xt0[:,1])
    ax.scatter(xt1[:,0], xt1[:,1])
# Out:
# <img src="data:image/png;base64,..." width="500">
# interactive(children=(IntSlider(value=499, description='generation', max=999), Output()), _dom_classes=('widget-interact',))

# %%
best_weights = population.population_history[0][0]
xt = relu(np.dot(X, best_weights[0]))
c0 = select_class(xt, y, class_val=0)
c1 = select_class(xt, y, class_val=1)
fig = plt.figure(figsize=(5,5))
ax = plt.axes()
ax.scatter(c0[:, 0], c0[:, 1], label='Class #0')
ax.scatter(c1[:, 0], c1[:, 1], label='Class #1')
ax.set_xlabel("$x_0$")
ax.set_ylabel("$x_1$")
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="500">
